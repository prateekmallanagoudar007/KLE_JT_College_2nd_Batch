# %%
print("Hello World");
# Out:
# Hello World

# %% [markdown]
# Python Second Program

# %%
print("*\n"*3)
# Out:
# *
# *
# *

# %%
print("*" * 3, sep="\n")
# Out:
# ***

# %%
name="Prateek"
print(name)
# Out:
# Prateek
